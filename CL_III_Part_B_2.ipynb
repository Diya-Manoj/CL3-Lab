# %% [markdown]
# # Problem Statement:
# Implement DEAP (Distributed Evolutionary Algorithms) using Python.

# %%
from deap import base, creator, tools
import random

# %% [markdown]
# ### 1. Create types

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

# %% [markdown]
# ### 2. Toolbox

# %%
toolbox = base.Toolbox()

# %% [markdown]
# #### Attribute (random numbers)

# %%
toolbox.register("attr_float", random.random)

# %% [markdown]
# #### Individual & population

# %%
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=5)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %% [markdown]
# ### 3. Evaluation function

# %%
def evaluate(individual):
    return sum(individual),

toolbox.register("evaluate", evaluate)

# %% [markdown]
# #### Operators

# %%
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=0.2)
toolbox.register("select", tools.selTournament, tournsize=3)

# %% [markdown]
# ### 4. Main algorithm

# %%
def main():
    pop = toolbox.population(n=10)

    # Evaluate initial population
    for ind in pop:
        ind.fitness.values = toolbox.evaluate(ind)

    # Evolution
    for gen in range(10):
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        # Crossover
        for c1, c2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.5:
                toolbox.mate(c1, c2)
                del c1.fitness.values, c2.fitness.values

        # Mutation
        for mutant in offspring:
            if random.random() < 0.2:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Re-evaluate
        invalid = [ind for ind in offspring if not ind.fitness.valid]
        for ind in invalid:
            ind.fitness.values = toolbox.evaluate(ind)

        pop[:] = offspring

    # Best individual
    best = tools.selBest(pop, 1)[0]
    print("Best Individual:", best)
    print("Best Fitness:", best.fitness.values)

# %%
main()
# Out:
# Best Individual: [2.842341729119222, 1.8359472339572942, 1.3073561035515087, 0.7541874750600248, 1.8379659003269877]
# Best Fitness: (8.577798442015037,)
